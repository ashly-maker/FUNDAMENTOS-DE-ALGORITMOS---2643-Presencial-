# %% [markdown]
# <a href="https://colab.research.google.com/github/ashly-maker/FUNDAMENTOS-DE-ALGORITMOS---2643-Presencial-/blob/main/Te_damos_la_bienvenida_a_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Coloco qué quiero hacer y qué me debe devolver
def area(a, b):
    return a * b

# Ingreso los valores que necesita la función
a = int(input('Ingrese la base del rectángulo: '))
b = int(input('Ingrese la altura del rectángulo: '))
if a == b:
  print("Ese NO es un rectángulo, es un cuadrado")
  # Condicional
else:
  print('El área del rectángulo es: ', multiplicar(a, b))
  # Imprimo el resultado

# %% [markdown]
# <a href="https://colab.research.google.com/github/ashly-maker/FUNDAMENTOS-DE-ALGORITMOS---2643-Presencial-/blob/main/PC2_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sección nueva

# %%
#Promedio de 3 notas: solicitar notas al estudiante de la UPN
n1 = int(input("Ingrese la nota #1: "))
n2 = int(input("Ingrese la nota #2: "))
n3 = int(input("Ingrese la nota #3: "))

#Calculamos el promedio
promedio = int(n1+n2+n3)/3

#Validamos la codiciom si cumple lo requerido par aprobar el curso de algoritmos
if promedio >= 11:
    print("Aprobo el curso con la nota ", int(promedio))
else:
    print("No aprobo, pague examen sustiturio")
# Out:
# Ingrese la nota #1: 12
# Ingrese la nota #2: 12
# Ingrese la nota #3: 10
# Aprobo el curso con la nota  11
